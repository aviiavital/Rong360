# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
user = pd.read_csv("Data/user.csv")

# %%
user_sum = user.groupby(['date']).sum()
user_sum.head(20)
# Out:
#         pv  pv_index_loan  pv_apply_total  pv_ask  pv_calculator  \
# date
# 52    8208            283             735     166              1
# 53    6809             82             644     339              2
# 54    5287             51             419      63              4
# 55    7944             97             572     230              4
# 56    8905             85             723     172              5
# 57    7582             61             613     169              6
# 58    6930             56             612      86              4
# 59    7167             46             611     110              0
# 60    6163             62             483     114              3
# 61    4463             35             400     101              5
# 62    7880             93             588     143             10
# 63    8173            103             711     132              3
# 64    8361             72             654     223              7
# 65    7907             82             625     173              4
# 66    7302             71             541     184              1
# 67    7501            112             619     174              9
# 68    6223             80             499     388              4
# 69    9296            147             787     183              1
# 70    7944            115             637     135             12
# 71    6974            101             573     122             18
#
#       order_count_loan  pv_daikuan  pv_credit  pv_search_daikuan  \
# date
# 52                 264        7088       1046               2599
# 53                 222        6252        550               2241
# 54                 152        4582        663               1819
# 55                 221        7136        707               2965
# 56                 288        7773        981               2960
# 57                 237        6591        832               2614
# 58                 205        6006        797               2335
# 59                 254        6279        744               2416
# 60                 168        5018       1142               1908
# 61                 141        3955        505               1575
# 62                 239        6647        918               2561
# 63                 245        7180        805               2634
# 64                 266        7091       1195               2793
# 65                 238        6752       1055               2739
# 66                 240        6360        833               2501
# 67                 242        6500        874               2458
# 68                 174        5224        969               1903
# 69                 284        8331        818               3243
# 70                 253        6919        921               2709
# 71                 222        6278        568               2552
#
#       pv_detail_daikuan
# date
# 52                 1528
# 53                 1348
# 54                 1047
# 55                 1557
# 56                 1789
# 57                 1406
# 58                 1319
# 59                 1470
# 60                 1139
# 61                  851
# 62                 1475
# 63                 1643
# 64                 1496
# 65                 1515
# 66                 1436
# 67                 1414
# 68                 1025
# 69                 1887
# 70                 1531
# 71                 1375

# %%
# columns to research: pv_daikuan, pv_credit, pv_search_daikuan, pv
user_sum.plot(figsize=(12,8))

# %%
user_sum['pv'].plot(figsize=(12,8))

# %%
user_sum2 = user_sum.reset_index()
user_sum2.head()
# Out:
#    date    pv  pv_index_loan  pv_apply_total  pv_ask  pv_calculator  \
# 0    52  8208            283             735     166              1
# 1    53  6809             82             644     339              2
# 2    54  5287             51             419      63              4
# 3    55  7944             97             572     230              4
# 4    56  8905             85             723     172              5
#
#    order_count_loan  pv_daikuan  pv_credit  pv_search_daikuan  \
# 0               264        7088       1046               2599
# 1               222        6252        550               2241
# 2               152        4582        663               1819
# 3               221        7136        707               2965
# 4               288        7773        981               2960
#
#    pv_detail_daikuan
# 0               1528
# 1               1348
# 2               1047
# 3               1557
# 4               1789

# %%
X0 = user_sum2.pv
diff0 = list()
for i in range(7, len(X0)):
    value0 = X0[i] - X0[i - 7]
    diff0.append(value0)
plt.plot(diff0)
plt.show()

# %%
X1 = user_sum2.pv
diff1 = list()
for i in range(30, len(X1)):
    value1 = X1[i] - X1[i - 30]
    diff1.append(value1)
plt.plot(diff1)
plt.show()

# %%
X2 = user_sum2.pv
diff2 = list()
for i in range(91, len(X2)):
    value2 = X2[i] - X2[i - 91]
    diff2.append(value2)
plt.plot(diff2)
plt.show()

# %%
Y0 = user_sum2.pv_search_daikuan
diffY0 = list()
for i in range(7, len(Y0)):
    value0 = Y0[i] - Y0[i - 7]
    diffY0.append(value0)
plt.plot(diffY0)
plt.show()

# %%
Y1 = user_sum2.pv_search_daikuan
diffY1 = list()
for i in range(7, len(Y1)):
    value1 = Y1[i] - Y1[i - 7]
    diffY1.append(value1)
plt.plot(diffY1)
plt.show()

# %%
Y2 = user_sum2.pv_search_daikuan
diffY2 = list()
for i in range(7, len(Y2)):
    value2 = Y2[i] - Y2[i - 7]
    diffY2.append(value2)
plt.plot(diffY2)
plt.show()
